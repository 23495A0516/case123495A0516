# %% [markdown]
# <a href="https://colab.research.google.com/github/23495A0516/case123495A0516/blob/main/Jagan(09%2C14_08).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as jagan
anil=jagan.read_csv('jagan.csv')
#print(anil)
#print(anil['Name'])
#print(anil[['Name','Target']])
#print(anil.columns)
#print(anil.shape)
#print(anil.info())
#print(anil.head(5))
#print(anil.tail(3))
#print(anil.describe())
#print(anil.sort_values('Name'))
# farmers schemes names
akash=anil[anil['Target']=='Farmers']
#print(akash['Name'])
ravindra=anil[anil['Name'].str.startswith('J')]
#print(ravindra['Name'])
rcb=anil[anil['Target'].str.contains('Students')]
print(rcb['Target'])
# Out:
# 3     Students from BPL Families
# 6                School Students
# 13    Government School Students
# Name: Target, dtype: object

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
maaz=pd.read_csv('energy.csv')

#print(maaz)
srh=maaz[maaz['State']=="Andhra"]
rcb=maaz[maaz['State']=="Karnataka"]

#Line chart
fig1,diag1=plt.subplots(2)
diag1[0].plot(srh['Date'],srh['Consumption'],color='red')
diag1[1].plot(rcb['Date'],rcb['Consumption'],color='blue')

#bar chart Telengana Tripura
rafi=maaz[maaz['State']=='Telengana']
cm=maaz[maaz['State']=='Tripura']
fig1,diag1=plt.subplots(2)
diag1[0].bar(rafi['Date'],rafi['Consumption'],color='red')
diag1[1].bar(cm['Date'],cm['Consumption'],color='blue')

#pie chart
state1="Delhi"
state2='Odisha'
state3='UP'
state4='Punjab'
chimtu=[state1,state2]
cse5=maaz[maaz['State']==state1]['Consumption'].sum()
cse6=maaz[maaz['State']==state2]['Consumption'].sum()
cse2=[cse5,cse6]
fig1,diag1=plt.subplots(2)
diag1[0].pie(cse2,labels=chimtu,autopct='%1.1f%%')

chimtu=[state3,state4]
cse5=maaz[maaz['State']==state3]['Consumption'].sum()
cse6=maaz[maaz['State']==state4]['Consumption'].sum()
cse2=[cse5,cse6]
fig1,diag1=plt.subplots(2)
diag1[1 n].pie(cse2,labels=chimtu,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x793138465600>,
# ...
#  [Text(0.34959578399465135, 1.042968258296083, 'UP'),
#   Text(-0.34959568634491406, -1.0429682910275981, 'Punjab')],
#  [Text(0.190688609451628, 0.5688917772524089, '39.7%'),
#   Text(-0.1906885561881349, -0.5688917951059625, '60.3%')])
